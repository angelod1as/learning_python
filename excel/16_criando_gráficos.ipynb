# %% [markdown]
# # Criando gráficos com Plotly

# %%
import plotly.express as px

# %%
import pandas as pd

df_vendas = pd.read_csv('datasets/vendas.csv', sep=';', decimal=',', index_col=0, parse_dates=True)
df_produtos = pd.read_csv('datasets/produtos.csv', sep=';', decimal=',', index_col=0)

df_produtos = df_produtos.rename(columns={'nome': 'produto'})
df_produtos = df_produtos[['produto', 'preco']]
df_vendas = pd.merge(left=df_vendas.reset_index(),
                    right=df_produtos,
                    on ='produto',
                    how ='left')
df_vendas = df_vendas.set_index('data')
df_vendas.head(10)
# Out:
#                             id_venda         filial           vendedor  \
# data
# 2023-01-20 08:00:56.384224         0         Canoas      Luis Fernando
# 2023-01-20 08:50:58.755843         1  Florianópolis       Mario Sérgio
# 2023-01-20 11:44:56.776745         2         Canoas    Carlos Henrique
# 2023-01-20 12:07:58.025749         3  Caxias do Sul  Rodrigo Vanzeloti
# 2023-01-20 12:49:56.606703         4      São Paulo      Cassia Moraes
# 2023-01-20 14:01:58.316971         5  Caxias do Sul     Mateus Kienzle
# 2023-01-20 14:37:56.577837         6        Lajeado   Juliano Faccioni
# 2023-01-20 15:16:57.086366         7      São Paulo      Claudio Bueno
# 2023-01-21 08:38:58.394180         8      São Paulo      Claudio Bueno
# 2023-01-21 10:53:58.316645         9         Canoas      Luis Fernando
#
#                                  produto      cliente_nome cliente_genero  \
# data
# 2023-01-20 08:00:56.384224    Tenis Nike     Sabrina Rieke       feminino
# 2023-01-20 08:50:58.755843  Tenis Adidas      Patsy Lovell       feminino
# 2023-01-20 11:44:56.776745  Tenis Adidas     John Crandall      masculino
# 2023-01-20 12:07:58.025749  Tenis Adidas    Mildred Mcleod       feminino
# 2023-01-20 12:49:56.606703      Tenis NB  Robert Mccormick      masculino
# 2023-01-20 14:01:58.316971      Tenis NB      Richard Kaeo      masculino
# 2023-01-20 14:37:56.577837    Tenis Fila       Carl Aurand      masculino
# 2023-01-20 15:16:57.086366      Tenis NB         Rita Hess       feminino
# 2023-01-21 08:38:58.394180    Tenis Fila    Lenny Harpster      masculino
# 2023-01-21 10:53:58.316645    Tenis Fila        Herman Lee      masculino
#
#                            forma_pagamento  preco
# data
# 2023-01-20 08:00:56.384224         credito    300
# 2023-01-20 08:50:58.755843         credito    450
# 2023-01-20 11:44:56.776745         credito    450
# 2023-01-20 12:07:58.025749         credito    450
# 2023-01-20 12:49:56.606703         credito    500
# 2023-01-20 14:01:58.316971             pix    500
# 2023-01-20 14:37:56.577837          boleto    250
# 2023-01-20 15:16:57.086366         credito    500
# 2023-01-21 08:38:58.394180         credito    250
# 2023-01-21 10:53:58.316645         credito    250

# %% [markdown]
# ## Gráficos de linha

# %%
df_vendas['dia_venda'] = df_vendas.index.date
df_vendas.head()
# Out:
#                             id_venda         filial           vendedor  \
# data
# 2023-01-20 08:00:56.384224         0         Canoas      Luis Fernando
# 2023-01-20 08:50:58.755843         1  Florianópolis       Mario Sérgio
# 2023-01-20 11:44:56.776745         2         Canoas    Carlos Henrique
# 2023-01-20 12:07:58.025749         3  Caxias do Sul  Rodrigo Vanzeloti
# 2023-01-20 12:49:56.606703         4      São Paulo      Cassia Moraes
#
#                                  produto      cliente_nome cliente_genero  \
# data
# 2023-01-20 08:00:56.384224    Tenis Nike     Sabrina Rieke       feminino
# 2023-01-20 08:50:58.755843  Tenis Adidas      Patsy Lovell       feminino
# 2023-01-20 11:44:56.776745  Tenis Adidas     John Crandall      masculino
# 2023-01-20 12:07:58.025749  Tenis Adidas    Mildred Mcleod       feminino
# 2023-01-20 12:49:56.606703      Tenis NB  Robert Mccormick      masculino
#
#                            forma_pagamento  preco   dia_venda
# data
# 2023-01-20 08:00:56.384224         credito    300  2023-01-20
# 2023-01-20 08:50:58.755843         credito    450  2023-01-20
# 2023-01-20 11:44:56.776745         credito    450  2023-01-20
# 2023-01-20 12:07:58.025749         credito    450  2023-01-20
# 2023-01-20 12:49:56.606703         credito    500  2023-01-20

# %%
df_vendas_dia = df_vendas.groupby(['dia_venda']).agg({'preco': 'sum', 'produto': 'count'})
df_vendas_dia
# Out:
#             preco  produto
# dia_venda
# 2023-01-20   3400        8
# 2023-01-21   2200        7
# 2023-01-22   3850        9
# 2023-01-23   1350        5
# 2023-01-24   2000        6
# ...           ...      ...
# 2023-09-22   3050        7
# 2023-09-23   1400        4
# 2023-09-24   2450        6
# 2023-09-25   1700        4
# 2023-09-26   3650        9
#
# [250 rows x 2 columns]

# %%
px.line(df_vendas_dia)

# %%
px.line(df_vendas_dia, y='preco')

# %% [markdown]
# ### Criando gráficos de barra

# %%
px.bar(df_vendas_dia, y='produto')

# %% [markdown]
# ### Criando gráficos de pizza

# %%
px.pie(df_vendas, names='vendedor', values='preco')
